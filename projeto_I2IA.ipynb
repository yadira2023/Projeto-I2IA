# %% [markdown]
# <a href="https://colab.research.google.com/github/yadira2023/Projeto-I2IA/blob/main/projeto_I2IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ThiagoDFMaia/projeto_i2a2.git
# Out:
# Cloning into 'projeto_i2a2'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 54 (delta 14), reused 37 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 233.88 KiB | 2.75 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# %cd projeto_i2a2
# Out:
# /content/projeto_i2a2

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git (to revision dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1) to /tmp/pip-install-2whj26v1/clip_f8144cc9821a401f94eb3c66780322f9
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-2whj26v1/clip_f8144cc9821a401f94eb3c66780322f9
#   Running command git rev-parse -q --verify 'sha^dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1'
#   Running command git fetch -q https://github.com/openai/CLIP.git dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Ignoring pywin32: markers 'sys_platform == "win32"' don't match your environment
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.5/104.5 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.4 MB/s eta 0:00:00
# ...
